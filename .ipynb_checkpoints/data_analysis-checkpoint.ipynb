# %%
## import libraries
import numpy as np 
import pandas as pd
from ast import literal_eval
import altair as alt

# %%
df = pd.read_csv('public/data/mc_final_w_emojis.csv', sep='\t')
df.sample(2)
# Out:
#      Unnamed: 0                                                url  \
# 144         144  https://newyork.craigslist.org/brk/mis/d/brook...
# 102         102  https://newyork.craigslist.org/mnh/mis/d/new-y...
#
#                     date                                              title  \
# 144  2024-06-05 16:57:00                   \nChurch Ave G Train (Brooklyn)
# 102  2024-06-13 20:36:00  \nwasian woman on uptown manhattan M train 11 AM
#
#            lat        lng                                               post  \
# 144  40.726327 -73.937010  I sat next to you last night around 8 30pm on ...
# 102  40.725345 -73.996439  In pink shirt jean shorts basketball shoes Wit...
#
#            Date                 Time  Weekday  ...    borough  \
# 144  2024-06-05  1900-01-01 16:57:00        2  ...   Brooklyn
# 102  2024-06-13  1900-01-01 20:36:00        3  ...  Manhattan
#
#                                         tokenized_post  \
# 144  [I, sat, next, to, you, last, night, around, 8...
# 102  [In, pink, shirt, jean, shorts, basketball, sh...
#
#                                                   verb  \
# 144              ['sit', 'get', 'get', 'wear', 'wear']
# 102  ['sit', 'read', 'do', 'have', 'try', 'say', 's...
#
#                                                   noun  \
# 144  ['night', '30pm', 'train', 'fit', 'dress', 'bu...
# 102  ['shirt', 'jean', 'short', 'basketball', 'shoe...
#
#                                                 adj  \
# 144  ['last', 'black', 'black', 'grayish', 'white']
# 102      ['pink', 'green', 'blue', 'black', 'cute']
#
#                       emojis_adj  \
# 144   ['🌗', '⚫', '⚫', None, '⚪']
# 102  [None, None, '🔵', '⚫', '😍']
#
#                                            emojis_noun  \
# 144                  ['🌃', None, '🚆', None, '👗', None]
# 102  [None, None, '🩳', '🏀', None, None, '🎧', None, ...
#
#                                  emojis_verb  \
# 144              ['💺', None, None, '👕', '👕']
# 102  ['💺', None, None, '✔️', None, '💬', '👀']
#
#                                                 emojis  \
# 144  ['🌗', '⚫', '⚫', None, '⚪', '💺', None, None, '👕...
# 102  [None, None, '🔵', '⚫', '😍', '💺', None, None, '...
#
#                                         cleaned_emojis
# 144  ['🌗', '⚫', '⚫', '⚪', '💺', '👕', '👕', '🌃', '🚆', ...
# 102  ['🔵', '⚫', '😍', '💺', '✔️', '💬', '👀', '🩳', '🏀',...
#
# [2 rows x 21 columns]

# %%
# convert time into labels
df['date'] = pd.to_datetime(df['date'])
df['Hour'] = df['date'].dt.hour

b = [0,4,8,12,16,20,24]
l = ['Late Night', 'Early Morning','Morning','Noon','Late Afternoon','Night']
df['session'] = pd.cut(df['Hour'], bins=b, labels=l, include_lowest=True)
df.sample(2)
# Out:
#     Unnamed: 0                                                url  \
# 85          85  https://newyork.craigslist.org/brx/mis/d/bronx...
# 30          30  https://newyork.craigslist.org/que/mis/d/jacks...
#
#                   date                        title        lat        lng  \
# 85 2024-06-17 03:15:00  \nDowntown 4 Train (Bronx)   40.858368 -73.903908
# 30 2024-06-24 21:28:00   \nTattooed arm (Elmhurst)   40.751300 -73.883000
#
#                                                  post        Date  \
# 85  You are a very handsome guy with nice arms You...  2024-06-17
# 30  Hey I asked you for a pic of your tattoo You a...  2024-06-24
#
#                    Time  Weekday  ...  \
# 85  1900-01-01 03:15:00        0  ...
# 30  1900-01-01 21:28:00        0  ...
#
#                                                  verb  \
# 85  ['take', 'get', 'm', 'sit', 'sound', 'hit', 'l...
# 30   ['ask', 'ask', 'finish', 'see', 'write', 'tell']
#
#                                                  noun  \
# 85  ['guy', 'arm', 'downtown', 'train', 'morning',...
# 30                          ['pic', 'tattoo', 'time']
#
#                                  adj         emojis_adj  \
# 85  ['handsome', 'nice', 'familiar']  ['👨', None, None]
# 30                          ['cute']              ['😍']
#
#                                      emojis_noun  \
# 85  ['👨', None, None, '🚆', '🌅', None, None, '👨']
# 30                             [None, None, '⌚']
#
#                                         emojis_verb  \
# 85  [None, None, None, '💺', None, None, None, None]
# 30                ['❓', '❓', None, '👀', None, None]
#
#                                                emojis  \
# 85  ['👨', None, None, None, None, None, '💺', None,...
# 30  ['😍', '❓', '❓', None, '👀', None, None, None, N...
#
#                     cleaned_emojis Hour     session
# 85  ['👨', '💺', '👨', '🚆', '🌅', '👨']    3  Late Night
# 30       ['😍', '❓', '❓', '👀', '⌚']   21       Night
#
# [2 rows x 23 columns]

# %%
df_noun_borough = df[['noun', 'borough', 'session']]
df_noun_borough['noun'] = df_noun_borough['noun'].apply(literal_eval)
df_exploded = df_noun_borough.explode('noun')

# # Group by 'borough' and get the value counts for 'nouns'
noun_counts = df_exploded.groupby(['borough', 'noun', 'session']).size().reset_index(name='count')
# noun_counts
value_counts = noun_counts.groupby('borough').apply(lambda x: x.nlargest(10, 'count')).reset_index(drop=True)


alt.Chart(value_counts).mark_bar().encode(
    y='noun',
    x='count',
    color='borough',
    column='session', 
    
).properties(
    width=120,
    height=300
)

## noun to replace t, tee, and shirt
## normalize the data
# Out:
# /var/folders/9m/cnc48ycx4xbc6n754r3xlv2h0000gn/T/ipykernel_14366/3637543359.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_noun_borough['noun'] = df_noun_borough['noun'].apply(literal_eval)
# /var/folders/9m/cnc48ycx4xbc6n754r3xlv2h0000gn/T/ipykernel_14366/3637543359.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   noun_counts = df_exploded.groupby(['borough', 'noun', 'session']).size().reset_index(name='count')
# /var/folders/9m/cnc48ycx4xbc6n754r3xlv2h0000gn/T/ipykernel_14366/3637543359.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   value_counts = noun_counts.groupby('borough').apply(lambda x: x.nlargest(10, 'count')).reset_index(drop=True)
# alt.Chart(...)

# %%
df_noun_borough = df[['noun', 'borough', 'session', 'Weekday']]
df_noun_borough['noun'] = df_noun_borough['noun'].apply(literal_eval)
df_exploded = df_noun_borough.explode('noun')

# # Group by 'borough' and get the value counts for 'nouns'
noun_counts = df_exploded.groupby(['borough', 'noun', 'session', 'Weekday']).size().reset_index(name='count')
noun_counts
# value_counts = noun_counts.groupby('borough').apply(lambda x: x.nlargest(5, 'count')).reset_index(drop=True)


# alt.Chart(value_counts).mark_bar().encode(
#     y='noun',
#     x='count',
#     color='borough',
#     column='session', 
#     row='Weekday'
# ).properties(
#     width=120,
#     height=300
# )

## noun to replace t, tee, and shirt
# Out:
# /var/folders/9m/cnc48ycx4xbc6n754r3xlv2h0000gn/T/ipykernel_14366/3896561739.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_noun_borough['noun'] = df_noun_borough['noun'].apply(literal_eval)
# /var/folders/9m/cnc48ycx4xbc6n754r3xlv2h0000gn/T/ipykernel_14366/3896561739.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   noun_counts = df_exploded.groupby(['borough', 'noun', 'session'])['Weekday'].size().reset_index(name='count')
#          borough  noun         session  count
# 0       Brooklyn  13th      Late Night      0
# 1       Brooklyn  13th   Early Morning      0
# 2       Brooklyn  13th         Morning      0
# 3       Brooklyn  13th            Noon      0
# 4       Brooklyn  13th  Late Afternoon      0
# ...          ...   ...             ...    ...
# 14755  The Bronx   zip   Early Morning      0
# 14756  The Bronx   zip         Morning      0
# 14757  The Bronx   zip            Noon      0
# 14758  The Bronx   zip  Late Afternoon      0
# 14759  The Bronx   zip           Night      0
#
# [14760 rows x 4 columns]

# %%
df_noun_borough = df[['noun', 'borough', 'Weekday']]
df_noun_borough['noun'] = df_noun_borough['noun'].apply(literal_eval)
df_exploded = df_noun_borough.explode('noun')
df_exploded
# # Group by 'borough' and get the value counts for 'nouns'
noun_counts = df_exploded.groupby(['borough', 'Weekday', 'noun']).size().reset_index(name='count')
# noun_counts
value_counts = noun_counts.groupby('borough').apply(lambda x: x.nlargest(5, 'count')).reset_index(drop=True)
value_counts

alt.Chart(value_counts).mark_bar().encode(
    y='noun',
    x='count',
    color='borough',
    column='Weekday'
)

## noun to replace t, tee, and shirt
# Out:
# /var/folders/9m/cnc48ycx4xbc6n754r3xlv2h0000gn/T/ipykernel_14366/56151571.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_noun_borough['noun'] = df_noun_borough['noun'].apply(literal_eval)
# /var/folders/9m/cnc48ycx4xbc6n754r3xlv2h0000gn/T/ipykernel_14366/56151571.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   value_counts = noun_counts.groupby('borough').apply(lambda x: x.nlargest(5, 'count')).reset_index(drop=True)
# alt.Chart(...)
